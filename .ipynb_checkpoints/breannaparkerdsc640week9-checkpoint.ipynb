# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.basemap import Basemap
import csv
import geopandas as gpd
from shapely.geometry import Point
import missingno as msn
import folium
from branca.element import Figure

# %%
#import data to dataframe
df1=pd.read_csv('costcos-geocoded.csv')
df1.head()
# Out:
#                      Address        City    State    Zip Code   Latitude  \
# 0   1205 N. Memorial Parkway  Huntsville  Alabama  35801-5930  34.743095
# 1       3650 Galleria Circle      Hoover  Alabama  35244-2346  33.377649
# 2     8251 Eastchase Parkway  Montgomery  Alabama       36117  32.363889
# 3  5225 Commercial Boulevard      Juneau   Alaska  99801-7210  58.359200
# 4       330 West Dimond Blvd   Anchorage   Alaska  99515-1950  61.143266
#
#     Longitude
# 0  -86.600955
# 1  -86.812420
# 2  -86.150884
# 3 -134.483000
# 4 -149.884217

# %%
#import data to dataframe
df2=pd.read_csv('ppg2008.csv')
df2.head()
# Out:
#            Name     G   MIN   PTS   FGM   FGA    FGP  FTM  FTA    FTP  ...  \
# 0    Dwyane Wade   79  38.6  30.2  10.8  22.0  0.491  7.5  9.8  0.765  ...
# 1   LeBron James   81  37.7  28.4   9.7  19.9  0.489  7.3  9.4  0.780  ...
# 2    Kobe Bryant   82  36.2  26.8   9.8  20.9  0.467  5.9  6.9  0.856  ...
# 3  Dirk Nowitzki   81  37.7  25.9   9.6  20.0  0.479  6.0  6.7  0.890  ...
# 4  Danny Granger   67  36.2  25.8   8.5  19.1  0.447  6.0  6.9  0.878  ...
#
#    3PA    3PP  ORB  DRB  TRB  AST  STL  BLK   TO   PF
# 0  3.5  0.317  1.1  3.9  5.0  7.5  2.2  1.3  3.4  2.3
# 1  4.7  0.344  1.3  6.3  7.6  7.2  1.7  1.1  3.0  1.7
# 2  4.1  0.351  1.1  4.1  5.2  4.9  1.5  0.5  2.6  2.3
# 3  2.1  0.359  1.1  7.3  8.4  2.4  0.8  0.8  1.9  2.2
# 4  6.7  0.404  0.7  4.4  5.1  2.7  1.0  1.4  2.5  3.1
#
# [5 rows x 21 columns]

# %%
#heatmap of dataset1
sns.heatmap(df1.corr(), annot = True, cmap='Blues')
# Out:
# C:\Users\brean\AppData\Local\Temp\ipykernel_22788\3220616026.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(), annot = True, cmap='Blues')
# <AxesSubplot: >

# %%
#heatmap of dataset2
sns.heatmap(df2.corr(), annot = True, cmap='Blues')
# Out:
# C:\Users\brean\AppData\Local\Temp\ipykernel_22788\3347667493.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot = True, cmap='Blues')
# <AxesSubplot: >

# %%
map = folium.Map(location=[df1.Latitude.mean(), df1.Longitude.mean()], zoom_start=34, control_scale=True)

# %%
for index, location in df1.iterrows():
    folium.Marker([location["Latitude"], location["Longitude"]], popup=location["City"]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db6c149b32ac25bb1f3a587df0b1d01c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db6c149b32ac25bb1f3a587df0b1d01c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db6c149b32ac25bb1f3a587df0b1d01c = L.map(
#                 &quot;map_db6c149b32ac25bb1f3a587df0b1d01c&quot;,
#                 {
#                     center: [37.98433440623501, -102.49959134652278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 34,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_db6c149b32ac25bb1f3a587df0b1d01c);
#
#
#
#
#
#             var tile_layer_a73ffffc5bd74cb20ec5214e8f1af632 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a73ffffc5bd74cb20ec5214e8f1af632.addTo(map_db6c149b32ac25bb1f3a587df0b1d01c);
#
#
#             var marker_b3f1455d0c9f8b06fd57a66d0eb0c0f5 = L.marker(
#                 [34.7430949, -86.6009553],
#                 {}
#             ).addTo(map_db6c149b32ac25bb1f3a587df0b1d01c);
#
#
#         var popup_e69bcedadf16ef19d3b9b09beaf80571 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b340986916595c112b0e205c2c31031c = $(`&lt;div id=&quot;html_b340986916595c112b0e205c2c31031c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Huntsville&lt;/div&gt;`)[0];
#                 popup_e69bcedadf16ef19d3b9b09beaf80571.setContent(html_b340986916595c112b0e205c2c31031c);
#
#
#
#         marker_b3f1455d0c9f8b06fd57a66d0eb0c0f5.bindPopup(popup_e69bcedadf16ef19d3b9b09beaf80571)
#         ;
#
#
#
#
#             var marker_53206206ed6d1d8fd2d023f5d6d1331a = L.marker(
#                 [33.377649, -86.81242],
#                 {}
#             ).addTo(map_db6c149b32ac25bb1f3a587df0b1d01c);
#
#
#         var popup_2fb4f85fff0fbc7a406450142e5c11cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9fc00bfdf77579542e5fb7ea27e9e7b6 = $(`&lt;div id=&quot;html_9fc00bfdf77579542e5fb7ea27e9e7b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hoover&lt;/div&gt;`)[0];
#                 popup_2fb4f85fff0fbc7a406450142e5c11cd.setContent(html_9fc00bfdf77579542e5fb7ea27e9e7b6);
#
#
#
#         marker_53206206ed6d1d8fd2d023f5d6d1331a.bindPopup(popup_2fb4f85fff0fbc7a406450142e5c11cd)
#         ;
#
#
#
#
#             var marker_43140cbee251f04e9ed8729e8e8b8dfb = L.marker(
#                 [32.363889, -86.150884],
#                 {}
#             ).addTo(map_db6c149b32ac25bb1f3a587df0b1d01c);
#
#
#         var popup_f71e1c19ad976d5d8bed65ced56a636a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_343487a3e7e368995d561bc2f8e108cf = $(`&lt;div id=&quot;html_343487a3e7e368995d561bc2f8e108cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Montgomery&lt;/div&gt;`)[0];
#                 popup_f71e1c19ad976d5d8bed65ced56a636a.setContent(html_343487a3e7e368995d561bc2f8e108cf);
#
#
#
#         marker_43140cbee251f04e9ed8729e8e8b8dfb.bindPopup(popup_f71e1c19ad976d5d8bed65ced56a636a)
#         ;
#
#
#
#
#             var marker_714ce363ba0f5ea149c625aa4d5f6120 = L.marker(
#                 [58.3592, -134.483],
#                 {}
#             ).addTo(map_db6c149b32ac25bb1f3a587df0b1d01c);
#
#
#         var popup_763adc5463c64e44d9e41bf5a089bdaf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f55b5551624334b0358f780735ca9cf7 = $(`&lt;div id=&quot;html_f55b5551624334b0358f780735ca9cf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Juneau&lt;/div&gt;`)[0];
#                 popup_763adc5463c64e44d9e41bf5a089bdaf.setContent(html_f55b5551624334b0358f780735ca9cf7);
#
#
#
#         marker_714ce363ba0f5ea149c625aa4d5f6120.bindPopup(popup_763adc5463c64e44d9e41bf5a089bdaf)
#         ;
#
#
#
#
#             var marker_351c974b7294ec942d5e8648f092b4e5 = L.marker(
#                 [61.143266, -149.884217],
#                 {}
#             ).addTo(map_db6c149b32ac25bb1f3a587df0b1d01c);
#
#
#         var popup_df029a8ea9e817d579752e33d19bd709 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30edc996ea090fd17f038b4cfef66138 = $(`&lt;div id=&quot;html_30edc996ea090fd17f038b4cfef66138&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anchorage&lt;/div&gt;`)[0];
#                 popup_df029a8ea9e817d579752e33d19bd709.setContent(html_30edc996ea090fd17f038b4cfef66138);
#
#
#
#         marker_351c974b7294ec942d5e8648f092b4e5.bindPopup(popup_df029a8ea9e817d579752e33d19bd709)
#         ;
#
#
#
#
#             var marker_c2b067e1e5b73304ac8ca7e775291290 = L.marker(
#                 [61.210815, -149.804337],

# %%
#second way to graph this (thought couldn't get the map to show up)
plt.scatter(x = df1.Longitude, y = df1.Latitude)
plt.show()

# %%
#lollipop chart
fig, axes = plt.subplots() 
axes.stem(df2['G'], df2['MIN'], 
          use_line_collection=True, basefmt=' ')  
plt.xlabel('G') 
plt.ylabel('MIN')
# Out:
# C:\Users\brean\AppData\Local\Temp\ipykernel_22788\2950383290.py:4: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   axes.stem(df2['G'], df2['MIN'],
# Text(0, 0.5, 'MIN')

# %%
#lollipop chart second way
my_range=range(1,len(df2.index)+1)

plt.stem(df2['G'])
plt.xticks(my_range, df2['MIN'])
# Out:
# ([<matplotlib.axis.XTick at 0x16fd36ebb50>,
#   <matplotlib.axis.XTick at 0x16fd36ebb20>,
#   <matplotlib.axis.XTick at 0x16fd36eb790>,
#   <matplotlib.axis.XTick at 0x16fd35be220>,
#   <matplotlib.axis.XTick at 0x16fd35becd0>,
#   <matplotlib.axis.XTick at 0x16fd35c37f0>,
#   <matplotlib.axis.XTick at 0x16fd35beee0>,
#   <matplotlib.axis.XTick at 0x16fd35cb430>,
#   <matplotlib.axis.XTick at 0x16fd35cbee0>,
#   <matplotlib.axis.XTick at 0x16fd35cf9d0>,
#   <matplotlib.axis.XTick at 0x16fd35d74c0>,
#   <matplotlib.axis.XTick at 0x16fd35cf640>,
#   <matplotlib.axis.XTick at 0x16fd35d7df0>,
#   <matplotlib.axis.XTick at 0x16fd35dc8e0>,
#   <matplotlib.axis.XTick at 0x16fd35e13d0>,
#   <matplotlib.axis.XTick at 0x16fd35e1e80>,
#   <matplotlib.axis.XTick at 0x16fd35dc160>,
#   <matplotlib.axis.XTick at 0x16fd35e77c0>,
#   <matplotlib.axis.XTick at 0x16fd35f02b0>,
#   <matplotlib.axis.XTick at 0x16fd35f0d60>,
#   <matplotlib.axis.XTick at 0x16fd35f5850>,
#   <matplotlib.axis.XTick at 0x16fd35e79d0>,
#   <matplotlib.axis.XTick at 0x16fd35f5d60>,
#   <matplotlib.axis.XTick at 0x16fd35fcbb0>,
#   <matplotlib.axis.XTick at 0x16fd36036a0>,
#   <matplotlib.axis.XTick at 0x16fd35fc370>,
#   <matplotlib.axis.XTick at 0x16fd3603fa0>,
#   <matplotlib.axis.XTick at 0x16fd3608a90>,
#   <matplotlib.axis.XTick at 0x16fd3610580>,
#   <matplotlib.axis.XTick at 0x16fd3610cd0>,
#   <matplotlib.axis.XTick at 0x16fd36085e0>,
#   <matplotlib.axis.XTick at 0x16fd3616a90>,
#   <matplotlib.axis.XTick at 0x16fd361b580>,
#   <matplotlib.axis.XTick at 0x16fd361bd00>,
#   <matplotlib.axis.XTick at 0x16fd3623b50>,
#   <matplotlib.axis.XTick at 0x16fd36039d0>,
#   <matplotlib.axis.XTick at 0x16fd362b490>,
#   <matplotlib.axis.XTick at 0x16fd362bf40>,
#   <matplotlib.axis.XTick at 0x16fd362fa30>,
#   <matplotlib.axis.XTick at 0x16fd362fb80>,
#   <matplotlib.axis.XTick at 0x16fd3553910>,
#   <matplotlib.axis.XTick at 0x16fd36162e0>,
#   <matplotlib.axis.XTick at 0x16fd362b700>,
#   <matplotlib.axis.XTick at 0x16fd3636d30>,
#   <matplotlib.axis.XTick at 0x16fd3641550>,
#   <matplotlib.axis.XTick at 0x16fd3636df0>,
#   <matplotlib.axis.XTick at 0x16fd362f4c0>,
#   <matplotlib.axis.XTick at 0x16fd3641ee0>,
#   <matplotlib.axis.XTick at 0x16fd364b700>,
#   <matplotlib.axis.XTick at 0x16fd364bee0>],
#  [Text(1, 0, '38.6'),
#   Text(2, 0, '37.7'),
#   Text(3, 0, '36.2'),
#   Text(4, 0, '37.7'),
#   Text(5, 0, '36.2'),
#   Text(6, 0, '39.0'),
#   Text(7, 0, '38.2'),
#   Text(8, 0, '36.6'),
#   Text(9, 0, '38.5'),
#   Text(10, 0, '34.5'),
#   Text(11, 0, '38.1'),
#   Text(12, 0, '37.2'),
#   Text(13, 0, '38.2'),
#   Text(14, 0, '34.1'),
#   Text(15, 0, '36.8'),
#   Text(16, 0, '39.5'),
#   Text(17, 0, '36.1'),
#   Text(18, 0, '36.4'),
#   Text(19, 0, '39.3'),
#   Text(20, 0, '35.1'),
#   Text(21, 0, '38.6'),
#   Text(22, 0, '36.8'),
#   Text(23, 0, '39.7'),
#   Text(24, 0, '36.6'),
#   Text(25, 0, '35.7'),
#   Text(26, 0, '37.4'),
#   Text(27, 0, '34.9'),
#   Text(28, 0, '38.1'),
#   Text(29, 0, '33.6'),
#   Text(30, 0, '35.9'),
#   Text(31, 0, '33.6'),
#   Text(32, 0, '36.9'),
#   Text(33, 0, '33.7'),
#   Text(34, 0, '35.6'),
#   Text(35, 0, '37.3'),
#   Text(36, 0, '37.1'),
#   Text(37, 0, '39.8'),
#   Text(38, 0, '31.1'),
#   Text(39, 0, '38.0'),
#   Text(40, 0, '37.5'),
#   Text(41, 0, '34.0'),
#   Text(42, 0, '36.3'),
#   Text(43, 0, '37.1'),
#   Text(44, 0, '31.9'),
#   Text(45, 0, '35.0'),
#   Text(46, 0, '30.1'),
#   Text(47, 0, '36.2'),
#   Text(48, 0, '35.3'),
#   Text(49, 0, '36.7'),
#   Text(50, 0, '29.9')])
